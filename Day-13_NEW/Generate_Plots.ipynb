# %%
import pandas as pd

df = pd.read_csv("FAOSTAT_data_2-18-2022.csv")
df
# Out:
#     Domain Code                        Domain  Area Code (FAO)  \
# 0           TCL  Crops and livestock products               10
# 1           TCL  Crops and livestock products               11
# 2           TCL  Crops and livestock products               52
# 3           TCL  Crops and livestock products               13
# 4           TCL  Crops and livestock products               16
# ..          ...                           ...              ...
# 108         TCL  Crops and livestock products              231
# 109         TCL  Crops and livestock products              234
# 110         TCL  Crops and livestock products              155
# 111         TCL  Crops and livestock products              236
# 112         TCL  Crops and livestock products              237
#
#                                    Area  Element Code          Element  \
# 0                             Australia          5910  Export Quantity
# ...

# %%
import matplotlib.pyplot as plt

df = df.sort_values(by='Value', ascending=False)
df = df[df["Value"] > 0.0]
fig = plt.figure(figsize=(18,7))
plt.scatter(df["Area"],df["Value"].to_list())
plt.xticks(rotation = 90,fontsize=10)
plt.yticks(fontsize=14)
plt.ylabel("Exported Cocoa Beans (Tonnes)", fontsize=16)
# plt.xlabel("Countries", fontsize=16)
plt.title("Cocoa Bean Exports by Country, 2018", fontsize=16)
plt.savefig("Linear_Plot_Cocoa_Beans_Export.jpg",bbox_inches='tight')
# plt.yscale("log")
# plt.show()

# %%
fig = plt.figure(figsize=(18,7))
plt.scatter(df["Area"],df["Value"].to_list())
plt.xticks(rotation = 90,fontsize=10)
plt.yticks(fontsize=14)
plt.ylabel("Exported Cocoa Beans (Tonnes)", fontsize=16)
# plt.xlabel("Countries", fontsize=16)
plt.title("Cocoa Bean Exports by Country, 2018", fontsize=16)
plt.yscale("log")
plt.savefig("Log_Plot_Cocoa_Beans_Export.jpg",bbox_inches='tight')
